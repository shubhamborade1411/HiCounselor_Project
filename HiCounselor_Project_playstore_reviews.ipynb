# %%
import pandas as pd
df = pd.read_csv('playstore_reviews.csv')
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
df.isna().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df['App'].value_counts()
# Out:
# CBS Sports App - Scores, News, Stats & Watch Live    320
# Bowmasters                                           320
# Angry Birds Classic                                  320
# Helix Jump                                           300
# 8 Ball Pool                                          300
#                                                     ...
# Easy Healthy Recipes                                  31
# Detector de Radares Gratis                            31
# Dresses Ideas & Fashions +3000                        31
# Drawing Clothes Fashion Ideas                         30
# Easy Hair Style Design                                30
# Name: App, Length: 1074, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 107457

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
df.isna().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
df.to_csv('cleaned_playstore_reviews.csv',index = False)

# %%
df[df['App']=='ASUS SuperNote']
# Out:
#                  App                                  Translated_Review  \
# 3379  ASUS SuperNote  Very useful. I'd like create new note template...
# 3382  ASUS SuperNote  All notes gone update, can't sign WebStorage a...
# 3383  ASUS SuperNote                     The nice page limit satisfied.
# 3386  ASUS SuperNote             Unless setup way wants work correctly.
# 3387  ASUS SuperNote                                           zf 3 max
# 3388  ASUS SuperNote                  Nice store copy save information.
# 3389  ASUS SuperNote                                         I love it!
# 3391  ASUS SuperNote                                        Awesome!!!!
# 3392  ASUS SuperNote  Typing supported write notes handwriting swipi...
# 3394  ASUS SuperNote  I'm trying send feedback, texts appearing scre...
# 3395  ASUS SuperNote  Very silly can't save notes that's page, save ...
# 3397  ASUS SuperNote  I three ASUS devices. This sync even single no...
# ...

# %%
df[df['App']=='Adobe Acrobat Reader']
# Out:
#                        App                                  Translated_Review  \
# 4132  Adobe Acrobat Reader  I really hate adobe reader fact I really like ...
# 4133  Adobe Acrobat Reader  As 6/10/18 I can't email attachments Samsung G...
# 4134  Adobe Acrobat Reader  It simply best kind. + scanning feature awesom...
# 4135  Adobe Acrobat Reader  Absolutely fantastic! The Adobe Scan automatic...
# 4136  Adobe Acrobat Reader  Adobe ruined it. I highlight text fast anymore...
# ...                    ...                                                ...
# 4306  Adobe Acrobat Reader  I want pdf reader...no logon cloud! Bye bye Ad...
# 4307  Adobe Acrobat Reader  Need lock mode allows user read pdfs without a...
# 4309  Adobe Acrobat Reader  Beautiful! It's like book Infront read. - take...
# 4310  Adobe Acrobat Reader  Highlighted text PDF stored Adobe cloud highli...
# 4311  Adobe Acrobat Reader  Can't rename documents latest update. Using An...
#
# ...
